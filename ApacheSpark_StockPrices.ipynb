# %% [markdown]
# <a href="https://colab.research.google.com/github/arpitsharma27/PythonPractice/blob/main/ApacheSpark_StockPrices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# install spark (change the version number if needed)
# !wget -q https://archive.apache.org/dist/spark/spark-3.5.0/spark-3.5.0-bin-hadoop3.tgz

# %%
# unzip the spark file to the current folder
# !tar xf spark-3.5.0-bin-hadoop3.tgz

# %%
# set your spark folder to your system path environment.
import os
os.environ["SPARK_HOME"] = "/content/spark-3.5.0-bin-hadoop3"

# %%
# install findspark using pip
# !pip install -q findspark

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import count, desc , col, max
import matplotlib.pyplot as plts

# %%
spark = SparkSession.builder.appName('spark_app').getOrCreate()

# %%
print(spark.version)
# Out:
# 3.5.0

# %%
pip install pyspark==3.5.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from pyspark import SparkContext
sc=SparkContext.getOrCreate()

# %%
spark = SparkSession.builder.appName('spark_app').getOrCreate()

# %%
amzn_csv_path='/content/drive/MyDrive/Coursera_ApacheSpark_StockPrice/AMZN.csv'
amzn_csv_df=spark.read.format('csv').option('inferSchema', True).option('header',True).load(amzn_csv_path)

# %%
amzn_csv_df.show()
# Out:
# +----------+-----------+-----------+-----------+-----------+-----------+--------+
# |      Date|       Open|       High|        Low|      Close|  Adj Close|  Volume|
# +----------+-----------+-----------+-----------+-----------+-----------+--------+
# |2020-03-04|1946.569946|     1978.0|     1922.0|1975.829956|1975.829956| 4772900|
# |2020-03-05|     1933.0|1960.719971|     1910.0|1924.030029|1924.030029| 4748200|
# |2020-03-06|     1875.0|1910.869995|     1869.5|1901.089966|1901.089966| 5273600|
# |2020-03-09|1773.859985| 1862.77002|1761.290039|1800.609985|1800.609985| 7813200|
# |2020-03-10|1870.880005| 1894.27002|1818.170044|1891.819946|1891.819946| 7133300|
# |2020-03-11|1857.849976|1871.319946|     1801.5|1820.859985|1820.859985| 5624800|
# |2020-03-12| 1721.97998|     1765.0|     1675.0|1676.609985|1676.609985|11346200|
# |2020-03-13|     1755.0|1786.310059|1680.619995|     1785.0|     1785.0| 8809700|
# ...

# %%
amzn_csv_rdd = amzn_csv_df.rdd.map(tuple)
type(amzn_csv_rdd)
#amzn_csv_rdd.collect()
# Out:
# pyspark.rdd.PipelinedRDD

# %%
amzn_csv_rdd = amzn_csv_df.rdd.map(lambda x: list(x))
type(amzn_csv_rdd)
#amzn_csv_rdd.collect()
# Out:
# pyspark.rdd.PipelinedRDD

# %%
data=[1,2,3,4]
distributedData=sc.parallelize(data)

# %%
print(type(distributedData))
print(type(sc))
# Out:
# <class 'pyspark.rdd.RDD'>
# <class 'pyspark.context.SparkContext'>

# %%
amzn_file='/content/drive/MyDrive/Coursera_ApacheSpark_StockPrice/AMZN.csv'
amzn_rdd=sc.textFile(amzn_file)
amzn_rdd.take(5)
# Out:
# ['Date,Open,High,Low,Close,Adj Close,Volume',
#  '2020-03-04,1946.569946,1978.000000,1922.000000,1975.829956,1975.829956,4772900',
#  '2020-03-05,1933.000000,1960.719971,1910.000000,1924.030029,1924.030029,4748200',
#  '2020-03-06,1875.000000,1910.869995,1869.500000,1901.089966,1901.089966,5273600',
#  '2020-03-09,1773.859985,1862.770020,1761.290039,1800.609985,1800.609985,7813200']

# %%
type(amzn_rdd)
# Out:
# pyspark.rdd.RDD

# %%
amzn_csv_rdd=amzn_rdd.map(lambda row:row.split(","))

# %%
amzn_csv_rdd.collect()
# Out:
# [['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'],
#  ['2020-03-04',
#   '1946.569946',
#   '1978.000000',
#   '1922.000000',
#   '1975.829956',
#   '1975.829956',
#   '4772900'],
#  ['2020-03-05',
#   '1933.000000',
#   '1960.719971',
#   '1910.000000',
#   '1924.030029',
#   '1924.030029',
#   '4748200'],
#  ['2020-03-06',
#   '1875.000000',
#   '1910.869995',
#   '1869.500000',
#   '1901.089966',
#   '1901.089966',
#   '5273600'],
#  ['2020-03-09',
#   '1773.859985',
#   '1862.770020',
#   '1761.290039',
#   '1800.609985',
#   '1800.609985',
#   '7813200'],
#  ['2020-03-10',
#   '1870.880005',
#   '1894.270020',
#   '1818.170044',
#   '1891.819946',
#   '1891.819946',
#   '7133300'],
#  ['2020-03-11',
#   '1857.849976',
#   '1871.319946',
#   '1801.500000',
#   '1820.859985',
#   '1820.859985',
#   '5624800'],
#  ['2020-03-12',
#   '1721.979980',
#   '1765.000000',
#   '1675.000000',
#   '1676.609985',
#   '1676.609985',
#   '11346200'],
#  ['2020-03-13',
# ...

# %%
tsla_file='/content/drive/MyDrive/Coursera_ApacheSpark_StockPrice/TSLA.csv'
tsla_rdd=sc.textFile(tsla_file)
tsla_rdd.take(5)
# Out:
# ['Date,Open,High,Low,Close,Adj Close,Volume',
#  '2020-03-04,152.792007,153.304001,144.945999,149.899994,149.899994,75245000',
#  '2020-03-05,144.753998,149.149994,143.613998,144.908005,144.908005,54263500',
#  '2020-03-06,138.000000,141.399994,136.854004,140.695999,140.695999,63314500',
#  '2020-03-09,121.078003,132.600006,121.000000,121.599998,121.599998,85368500']

# %%
type(tsla_rdd)
# Out:
# pyspark.rdd.RDD

# %%
tsla_csv_rdd=tsla_rdd.map(lambda row:row.split(","))

# %%
#tsla_csv_rdd.collect()

# %%
goog_file='/content/drive/MyDrive/Coursera_ApacheSpark_StockPrice/GOOG.csv'
goog_rdd=sc.textFile(goog_file)
goog_rdd.take(5)
# Out:
# ['Date,Open,High,Low,Close,Adj Close,Volume',
#  '2020-03-04,1359.229980,1388.089966,1343.109985,1386.520020,1386.520020,1913300',
#  '2020-03-05,1350.199951,1358.910034,1305.099976,1319.040039,1319.040039,2561300',
#  '2020-03-06,1277.060059,1306.219971,1261.050049,1298.410034,1298.410034,2660600',
#  '2020-03-09,1205.300049,1254.760010,1200.000000,1215.560059,1215.560059,3365400']

# %%
goog_csv_rdd=goog_rdd.map(lambda row:row.split(","))
#goog_csv_rdd.collect()

# %%
goog_df=csv_rdd.toDF(['date','open','high','low','close','adjclose','volume'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-96139c3b807f> in <cell line: 1>()
# ----> 1 goog_df=csv_rdd.toDF(['date','open','high','low','close','adjclose','volume'])
#
# NameError: name 'csv_rdd' is not defined

# %%
goog_df.take(5)

# %%
amazon_file='/content/drive/MyDrive/Coursera_ApacheSpark_StockPrice/AMZN.csv'
amazon_df=spark.read.load(amazon_file,format='com.databricks.spark.csv',header='True',inferSchema='True')

# %%
amazon_df.take(2)

# %%
amazon_df.printSchema()

# %%
amazon_df.count()

# %%
amazon_df.show()

# %%
import pandas as pd

# %%
amazon_df.toPandas().head(5)
